# %% [markdown]
# <a href="https://colab.research.google.com/github/thanga-v2/Transformers/blob/main/Neural_Machine_Translation_En_Deutsch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Converting phrases from One language to an another.
#
# It follows Seq2Seq Architecture

# %%
from transformers import pipeline

# %%
eng2deutsch = pipeline("translation", model="Helsinki-NLP/opus-mt-en-de")
# Out:
# config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
eng2deutsch("I born on 29 March 1996")
# Out:
# [{'translation_text': 'Ich bin am 29. März 1996 geboren'}]
